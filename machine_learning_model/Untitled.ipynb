# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

# %%
data = pd.read_csv('medical_data.csv')
data.head(100)
# Out:
#    animal_type  record_no     status       date record_type  \
# 0          Cat  M44244776  Completed  23-Mar-18     Surgery
# 1          Cat  M43625283  Completed   2-Feb-18     Surgery
# 2          Cat  M43817874  Completed  30-Jan-18     Surgery
# 3          Cat  M43511736  Completed  25-Jan-18     Surgery
# 4          Cat  M44784946  Completed   3-May-18     Surgery
# ..         ...        ...        ...        ...         ...
# 95         Cat  M46267241  Completed  31-Jul-18     Surgery
# 96         Cat  M46354339  Completed   3-Aug-18     Surgery
# 97         Cat  M46899854  Completed   7-Sep-18     Surgery
# 98         Cat  M46327445  Completed   3-Aug-18     Surgery
# 99         Cat  M46354358  Completed   3-Aug-18     Surgery
#
#        record_sub_type
# 0   HSWC Spay Resident
# 1   HSWC Spay Resident
# 2   HSWC Spay Resident
# 3   HSWC Neut Resident
# 4   HSWC Spay Resident
# ..                 ...
# 95  HSWC Neut Resident
# 96  HSWC Spay Resident
# 97  HSWC Spay Resident
# 98  HSWC Spay Resident
# 99  HSWC Spay Resident
#
# [100 rows x 6 columns]

# %%
df = data.loc[(data.record_sub_type == 'Neuter') | (data.record_sub_type == 'Spay')]
df.head()
# Out:
#     animal_type  record_no     status       date record_type record_sub_type
# 9           Cat  M43589053  Completed  30-Jan-18     Surgery            Spay
# 122         Cat  M47141232  Completed  21-Sep-18     Surgery          Neuter
# 123         Cat  M47130392  Completed  21-Sep-18     Surgery          Neuter
# 124         Cat  M47130425  Completed  21-Sep-18     Surgery          Neuter
# 125         Cat  M47130644  Completed  21-Sep-18     Surgery            Spay

# %%
df = df.drop(['record_no','status','record_type'], axis = 1)
df.head()
# Out:
#     animal_type       date record_sub_type
# 9           Cat  30-Jan-18            Spay
# 122         Cat  21-Sep-18          Neuter
# 123         Cat  21-Sep-18          Neuter
# 124         Cat  21-Sep-18          Neuter
# 125         Cat  21-Sep-18            Spay

# %%
# get spay and neuter count for each month

# %%
#get month from date
df['month_of_date'] = df['date'].dt.month
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ffa5dc67841f> in <module>
#       1 #get month from date
# ----> 2 df['month_of_date'] = df['date'].dt.month
#       3 df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     492             return PeriodProperties(data, orig)
#     493
# --> 494         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values
